# %%
import re
import requests
from bs4 import BeautifulSoup

site = 'https://in.linkedin.com/'

response = requests.get(site)

soup = BeautifulSoup(response.text, 'html.parser')
img_tags = soup.find_all('img')

urls = [img['src'] for img in img_tags]


for url in urls:
    filename = re.search(r'/([\w_-]+[.](jpg|gif|png))$', url)
    if not filename:
         print("Regex didn't match with the url: {}".format(url))
         continue
    with open(filename.group(1), 'wb') as f:
        if 'http' not in url:
            # sometimes an image source can be relative 
            # if it is provide the base url which also happens 
            # to be the site variable atm. 
            url = '{}{}'.format(site, url)
        response = requests.get(url)
        f.write(response.content)

# %%
import re,urllib,requests,math
# from io import StringIO
from bs4 import BeautifulSoup
from PIL import Image

site = 'https://www.amazon.in/'
response = requests.get(site)
soup = BeautifulSoup(response.text, 'html.parser')
img_tags = soup.find_all('img',src=True)
# print(img_tags)
# for img in img_tags:
#     print(img['src'])

for img in img_tags:
    try:
        
        img_size = requests.get(img['src']).content
        
#         image = Image.open(urllib.request.urlopen(img['src']))

#         width, height = image.size
        print(img['src'])
        print(f"{len(img_size)/1000}Kb")
#         print("File Size In Bytes:- "+str(len(image.fp.read()))
#         k = (width*height*3)/(1024*1024)
#         print(img['src'])
#         print(f"{width}x{height}")
    except:
              print("Some Problem in Url")
#     print(img['src'])
#     file = StringIO(requests.get(site))
# Out:
# https://images-eu.ssl-images-amazon.com/images/G/31/gno/sprites/nav-sprite-global-1x-hm-dsk-reorg._CB405936311_.png
# 10.63Kb
# https://images-eu.ssl-images-amazon.com/images/G/31/AmazonVideo/2021/X-site/Multititle/Feb/EN/400x39-SWM_Dec._CB659576884_.jpg
# 4.783Kb
# https://images-eu.ssl-images-amazon.com/images/G/31/img21/Wireless/Apple/FebFPF/RegularPrice/D20999140_IN_WL_FPF_iPhone12_mini_FPF_FEB_DesktopTallHero_1500x600._CB660462078_.jpg
# 26.827Kb
# https://images-eu.ssl-images-amazon.com/images/G/31/img19/AmazonPay/Boson/Sid/CCBP/DesktopGateway_CategoryCard_379x304_CCBP._SY304_CB413372299_.jpg
# 5.095Kb
# https://images-eu.ssl-images-amazon.com/images/G/31/img20/AmazonBrands/GW/2-1_186x116._SY116_CB430773131_.jpg
# 5.063Kb
# https://images-eu.ssl-images-amazon.com/images/G/31/img20/AmazonBrands/GW/2-4_186x116._SY116_CB430773130_.jpg
# 5.891Kb
# https://images-eu.ssl-images-amazon.com/images/G/31/img20/AmazonBrands/GW/2-2_186x116._SY116_CB430773130_.jpg
# 6.112Kb
# ...
